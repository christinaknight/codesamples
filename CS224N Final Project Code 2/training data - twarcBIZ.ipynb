# %%
# !pip3 install twarc
# !pip install --upgrade twarc
# Out:
# Requirement already satisfied: twarc in /usr/local/lib/python3.7/dist-packages (2.9.5)
# Requirement already satisfied: click<9,>=7 in /usr/local/lib/python3.7/dist-packages (from twarc) (7.1.2)
# Requirement already satisfied: click-config-file>=0.6 in /usr/local/lib/python3.7/dist-packages (from twarc) (0.6.0)
# Requirement already satisfied: click-plugins>=1 in /usr/local/lib/python3.7/dist-packages (from twarc) (1.1.1)
# Requirement already satisfied: humanize>=3.9 in /usr/local/lib/python3.7/dist-packages (from twarc) (4.0.0)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from twarc) (4.63.0)
# Requirement already satisfied: requests-oauthlib>=1.3 in /usr/local/lib/python3.7/dist-packages (from twarc) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8 in /usr/local/lib/python3.7/dist-packages (from twarc) (2.8.2)
# Requirement already satisfied: configobj>=5.0.6 in /usr/local/lib/python3.7/dist-packages (from click-config-file>=0.6->twarc) (5.0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from configobj>=5.0.6->click-config-file>=0.6->twarc) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from humanize>=3.9->twarc) (4.11.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=1.3->twarc) (3.2.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=1.3->twarc) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (2021.10.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->humanize>=3.9->twarc) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->humanize>=3.9->twarc) (3.10.0.2)
# Requirement already satisfied: twarc in /usr/local/lib/python3.7/dist-packages (2.9.5)
# Requirement already satisfied: click-config-file>=0.6 in /usr/local/lib/python3.7/dist-packages (from twarc) (0.6.0)
# Requirement already satisfied: click<9,>=7 in /usr/local/lib/python3.7/dist-packages (from twarc) (7.1.2)
# Requirement already satisfied: humanize>=3.9 in /usr/local/lib/python3.7/dist-packages (from twarc) (4.0.0)
# Requirement already satisfied: click-plugins>=1 in /usr/local/lib/python3.7/dist-packages (from twarc) (1.1.1)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.7/dist-packages (from twarc) (4.63.0)
# Requirement already satisfied: requests-oauthlib>=1.3 in /usr/local/lib/python3.7/dist-packages (from twarc) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8 in /usr/local/lib/python3.7/dist-packages (from twarc) (2.8.2)
# Requirement already satisfied: configobj>=5.0.6 in /usr/local/lib/python3.7/dist-packages (from click-config-file>=0.6->twarc) (5.0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from configobj>=5.0.6->click-config-file>=0.6->twarc) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from humanize>=3.9->twarc) (4.11.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=1.3->twarc) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=1.3->twarc) (3.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->requests-oauthlib>=1.3->twarc) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->humanize>=3.9->twarc) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->humanize>=3.9->twarc) (3.7.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/CS224N_Final_Project
# Out:
# /content/drive/.shortcut-targets-by-id/1j5kyxZYGHOBbhVzDyhjBzmHe7u7clqVc/CS224N_Final_Project

# %%
from twarc import Twarc


consumer_key="ukc4AdhfcaGaDltF3tBiLi8jQ"
consumer_secret="mHpOF3VuWpCCubYlgLaWLd8wGYOu625pO5XMLHw4FXebZbcrxr"
access_token="1156238956779986947-ygcAES31ByJDSXjX9XNI4Fr94kfhUw"
access_token_secret="ckEW3z6oWa5PB9SiHjgJI2fkg9lLnGkjVwKHKxmWwTl7i"

# %%
#twarc2 configure
# Out:
#   File "<ipython-input-71-172db35caa84>", line 1
#     twarc2 configure
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd 


t = Twarc(consumer_key, consumer_secret, access_token, access_token_secret)

strs = []
sent = []
i = 0
p = 0

#df = pd.read_csv('tweets2hydrate/corona-tweets-01.csv')
csv_dict = pd.read_csv('tweets2hydrate/corona-tweets-600.csv', header=None, index_col=0, squeeze=True).to_dict()
#print(csv_dict[1240727808340414464])

#for tweet in t.hydrate(open('tweets2hydrate/may-2020-unlabeled-full.csv')):
for tweet in t.hydrate(open('tweets2hydrate/corona-tweets-600.csv')):
    i += 1
    
    tweet_id = tweet['id']
    if i == 100:
      print(tweet)
      break
    strs.append(tweet['full_text'])
    if csv_dict[tweet_id] > 0 and csv_dict[tweet_id] <= 1: # positive sentiment
      sent.append(2)
    elif csv_dict[tweet_id] < 0 and csv_dict[tweet_id] >= -1: # negative sentiment
      sent.append(0)
    elif csv_dict[tweet_id] == 0:
      sent.append(1)
print(type(sent[1]))
total = pd.DataFrame([strs, sent])
total = pd.DataFrame.transpose(total)

total.to_csv('try.csv' , index = True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-216-cc6a7e652eda> in <module>()
#      15
#      16 #for tweet in t.hydrate(open('tweets2hydrate/may-2020-unlabeled-full.csv')):
# ---> 17 for tweet in t.hydrate(open('tweets2hydrate/corona-tweets-600.csv')):
#      18     i += 1
#      19
#
# /usr/local/lib/python3.7/dist-packages/twarc/client.py in hydrate(self, iterator, trim_user)
#     612                         "include_ext_alt_text": "true",
#     613                         "include_entities": "true",
# --> 614                         "trim_user": trim_user,
#     615                     },
#     616                 )
#
# /usr/local/lib/python3.7/dist-packages/twarc/decorators.py in new_f(*args, **kwargs)
#      86                 time.sleep(seconds)
#      87             else:
# ---> 88                 resp.raise_for_status()
#      89
#      90     return new_f
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in raise_for_status(self)
#     939
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#     943     def close(self):
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.twitter.com/1.1/statuses/lookup.json

# %%
import pandas as pd
lst_csvs = ['tweets2hydrate/tries/1.csv','tweets2hydrate/tries/2.csv', 'tweets2hydrate/tries/3.csv', 'tweets2hydrate/tries/4.csv', 'tweets2hydrate/tries/5.csv', 'tweets2hydrate/tries/6.csv', 'tweets2hydrate/tries/7.csv', 'tweets2hydrate/tries/8.csv']
lst_dfs = []
for path in lst:
  df = pd.read_csv(path)
  lst_dfs.append(df)
  
pd.concat(lst_dfs).to_csv('here.csv', index=False)

# %%
df_1 = pd.read_csv('here.csv')
df_2 = pd.read_csv('vaccine-senitment-hydrated.csv')

pd.concat([df_1, df_2]).to_csv('final-train.csv', index=False)
